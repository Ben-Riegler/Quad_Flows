# %%
from Quad_Dyn import DS

# %%
X = DS("10*(y-x)","x*(28-z)-y","x*y-8*z/3")

# %%
X.plot3D([0, 0.4, 1], 7000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
H = DS("y","z","x**2 - y**2 + 2* x* z + y* z + 1")

# %%
H.plot3D([1, 0, -4], 50000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
N = DS("z","x-y","- 4 *x** 2 + 8* x *y + y* z -0.1")

# %%
N.plot3D([0.5, 0, -1], 20000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
K = DS("y","-x-y*z","x*y + 0.5 *x**2 - 1.3")

# %%
K.plot3D([0, 0.1, 0], 100000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
T = DS("y","-x+z","z - 2 *x *y - 1.8* x* z -1")

# %%
T.plot3D([0, 1.6, 3], 20000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
M = DS("-y","x+z","2*y**2 + x*z - 0.35")

# %%
M.plot3D([-4.5, 0.4, 1], 30000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
